# %% [markdown]
# # **NAME : Shivakumar R Hombal**
#
# ##**Task-1 - Prediction Using Supervised Machine Learning**
#
# ##**The aim of this task is to predict the percentage of an student based on the no. of study hours.**
#
#
# ###**The below code block is used to import all the necessary libraries to develope a Supervised Machine Learning model**

# %%
import pandas as pd
import seaborn as sns
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %% [markdown]
# ##**Importing the dataset**

# %%
path = "http://bit.ly/w-data"
data = pd.read_csv(path)
print("Data imported successfully")
data.head()
# Out:
# Data imported successfully
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
#To check if the data contains null values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %% [markdown]
# ##**To see the necessary statistics of the given data**

# %%
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# ##**Ploting a graph for the given dataset**

# %%
plt.xlabel('Hours', fontsize = 15)
plt.ylabel('Scores', fontsize = 15)
plt.title('Hours studied vs Score', fontsize = 10)
plt.scatter(data.Hours,data.Scores)
plt.show()
print("This Scatter plot indicates the positive linear relation between the number of hours studied and percentage of score")
# Out:
# This Scatter plot indicates the positive linear relation between the number of hours studied and percentage of score

# %% [markdown]
# ##**Preparing the dataset**

# %%
X = data.drop(['Scores'], axis= 1)
y = data['Scores']

# %% [markdown]
# ###**Now that we have our attributes and labels, the next step is to split this data into training and test sets.**
# ###**We'll do this by using Scikit-Learn's built-in train_test_split() method**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##**Training the Machine Learning model**

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
print("Training Complet !")
# Out:
# Training Complet !

# %% [markdown]
# ##**Plotting the regression line**

# %%
line = reg.coef_*x + reg.intercept_
plt.scatter(X_train, y_train)
plt.plot(X, line)
plt.xlabel('Hours studied')
plt.ylabel('Percentage Score')
plt.grid()
plt.show()

# %% [markdown]
# ##**Testing the model**

# %%
plt.scatter(X_test, y_test)
plt.plot(X, line)
plt.xlabel('Hours studied')
plt.ylabel('Percentage Score')
plt.grid()
plt.show()

# %% [markdown]
# ##**Making Predictions**

# %%
print(X_test)
y_pred = reg.predict(X_test)
# Out:
#     Hours
# 5     1.5
# 2     3.2
# 19    7.4
# 16    2.5
# 11    5.9

# %% [markdown]
# ##**Comparing Actual score vs Predicted score**

# %%
compare_scores = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
compare_scores
# Out:
#     Actual  Predicted
# 5       20  16.884145
# 2       27  33.732261
# 19      69  75.357018
# 16      30  26.794801
# 11      62  60.491033

# %%
from sklearn import metrics
print('Accuracy of actual and predicted r-squared:', metrics.r2_score(y_test, y_pred))
print("The accuracy of the developed model is above 90% indicating that the model is good")
# Out:
# Accuracy of actual and predicted r-squared: 0.9454906892105354
# The accuracy of the developed model is above 90% indicating that the model is good

# %% [markdown]
# ##**Checking the model's accuracy and its precision by applying various metrics checking formulas**

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
MSE = metrics.mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(MSE)
print("Mean Squared Error      = ", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error = ", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Squared Error      =  21.598769307217456
# Root Mean Squared Error =  4.647447612100373

# %% [markdown]
# ##**Calculating the score for a student who has studied for 9.25 hours.**

# %%
hrs = np.array(9.25) .reshape(-1,1)
pr = reg.predict(hrs)
print('The hours of student studied : ', float(hrs))
print('The Percentage of marks student scored : ', float(pr))
# Out:
# The hours of student studied :  9.25
# The Percentage of marks student scored :  93.69173248737539

# %% [markdown]
# #**The aim of this Machine Learning model has been achieved.**
